# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjid-007/ML-Lab-Final/blob/main/OLD_ASSIGNMENT/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import loadtxt
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Input Variables:
#
#
# ---
#
#
# 1. Number of times pregnant
#
# 2. Plasma glucose concentration at 2 hours in an oral glucose tolerance test
#
# 3. Diastolic blood pressure (mm Hg)
#
# 4. Triceps skin fold thickness (mm)
#
# 5. 2-hour serum insulin (mu U/ml)
#
# 6. Body mass index (weight in kg/(height in m)^2)
#
# 7. Diabetes pedigree function
#
# 8. Age (years)
#
#
# Output Variable:
#
#
# ---
#
# Class variable (0 or 1)

# %%
data_path = '/content/drive/MyDrive/ML-DATASET/2. Labs/4. Neural Network/nn_data.txt'
dataset = pd.read_csv(data_path, header=None)
dataset.shape
print(dataset.head())
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
# split into input (X) and output (y) variables
# split into input (X) and output (y) variables
X = dataset.iloc[:,0:8]
y = dataset.iloc[:,8]

# %%
X.head()
# Out:
#    0    1   2   3    4     5      6   7
# 0  6  148  72  35    0  33.6  0.627  50
# 1  1   85  66  29    0  26.6  0.351  31
# 2  8  183  64   0    0  23.3  0.672  32
# 3  1   89  66  23   94  28.1  0.167  21
# 4  0  137  40  35  168  43.1  2.288  33

# %%
# define the keras model
model = Sequential()
model.add(Dense(8, input_shape=(8,), activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 1s 2ms/step - loss: 1.7928 - accuracy: 0.5938
# Epoch 2/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8599 - accuracy: 0.6510
# Epoch 3/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7364 - accuracy: 0.6419
# Epoch 4/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6943 - accuracy: 0.6380
# Epoch 5/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6742 - accuracy: 0.6602
# Epoch 6/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6589 - accuracy: 0.6471
# Epoch 7/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6483 - accuracy: 0.6536
# Epoch 8/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6500 - accuracy: 0.6602
# Epoch 9/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6283 - accuracy: 0.6784
# Epoch 10/100
# ...

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5405 - accuracy: 0.7292
# Accuracy: 72.92

# %%
# make class predictions with the model
predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
	print(' %d (expected %d)' % ( predictions[i], y[i]))
# Out:
# 24/24 [==============================] - 0s 1ms/step
#  0 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
#  0 (expected 0)
#  0 (expected 1)
